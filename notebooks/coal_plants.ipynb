# %%
import pandas as pd
pd.set_option('display.max_columns', 500)
import numpy as np

# %%
df = pd.read_csv("D:\Work\WB\LDT\countries\SRB\\raw_data\SRB\DATA\power\electricity-generation_emissions_sources.csv")
df
# Out:
#      source_id               source_name source_type iso3_country sector  \
# 0     25450758  Kolubara A power station        coal          SRB  power
# 1     25450758  Kolubara A power station        coal          SRB  power
# 2     25450758  Kolubara A power station        coal          SRB  power
# 3     25450758  Kolubara A power station        coal          SRB  power
# 4     25450758  Kolubara A power station        coal          SRB  power
# ..         ...                       ...         ...          ...    ...
# 120   25455686   Zrenjanin power station         gas          SRB  power
# 121   25455686   Zrenjanin power station         gas          SRB  power
# 122   25455686   Zrenjanin power station         gas          SRB  power
# 123   25455686   Zrenjanin power station         gas          SRB  power
# 124   25455686   Zrenjanin power station         gas          SRB  power
#
#                   subsector           start_time             end_time  \
# ...

# %%
df['source_type'].value_counts()
# Out:
# source_type
# coal                 80
# gas                  40
# gas, other_fossil     5
# Name: count, dtype: int64

# %%
df['subsector'].value_counts()
# Out:
# subsector
# electricity-generation    125
# Name: count, dtype: int64

# %%
df_coal = df[df['source_type'] == 'coal']
df_coal
# Out:
#     source_id                 source_name source_type iso3_country sector  \
# 0    25450758    Kolubara A power station        coal          SRB  power
# 1    25450758    Kolubara A power station        coal          SRB  power
# 2    25450758    Kolubara A power station        coal          SRB  power
# 3    25450758    Kolubara A power station        coal          SRB  power
# 4    25450758    Kolubara A power station        coal          SRB  power
# ..        ...                         ...         ...          ...    ...
# 75   25450762  Nikola Tesla power station        coal          SRB  power
# 76   25450762  Nikola Tesla power station        coal          SRB  power
# 77   25450762  Nikola Tesla power station        coal          SRB  power
# 78   25450762  Nikola Tesla power station        coal          SRB  power
# 79   25450762  Nikola Tesla power station        coal          SRB  power
#
#                  subsector           start_time             end_time      lat  \
# ...

# %%
df_coal['gas'].value_counts()
# Out:
# gas
# ch4           16
# co2           16
# co2e_100yr    16
# co2e_20yr     16
# n2o           16
# Name: count, dtype: int64

# %%
df_coal[df_coal['gas'] == 'co2e_20yr']
# Out:
#     source_id                 source_name source_type iso3_country sector  \
# 3    25450758    Kolubara A power station        coal          SRB  power
# 8    25450758    Kolubara A power station        coal          SRB  power
# 13   25450758    Kolubara A power station        coal          SRB  power
# 18   25450758    Kolubara A power station        coal          SRB  power
# 23   25450760      Kostolac power station        coal          SRB  power
# 28   25450760      Kostolac power station        coal          SRB  power
# 33   25450760      Kostolac power station        coal          SRB  power
# 38   25450760      Kostolac power station        coal          SRB  power
# 43   25450761        Morava power station        coal          SRB  power
# 48   25450761        Morava power station        coal          SRB  power
# 53   25450761        Morava power station        coal          SRB  power
# 58   25450761        Morava power station        coal          SRB  power
# ...
