# %%
import os
import sys
import warnings
warnings.filterwarnings('ignore')

import pandas as pd
import numpy as np
import geopandas as gpd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
poly = gpd.read_file('D:\Work\WB\LDT\countries\SRB\serbia-240101-free.shp\gis_osm_buildings_a_free_1.shp')

# %%
poly
# Out:
#              osm_id  code    fclass  name   type  \
# 0          12528237  1500  building  Maxi   None
# 1          23066447  1500  building  None  house
# 2          23066453  1500  building  None   None
# 3          23066455  1500  building  None   None
# 4          23066456  1500  building  None   None
# ...             ...   ...       ...   ...    ...
# 1383932  1236107404  1500  building  None   None
# 1383933  1236107405  1500  building  None   None
# 1383934  1236107406  1500  building  None   None
# 1383935  1236107817  1500  building  None  house
# 1383936  1236107887  1500  building  None   None
#
#                                                   geometry
# 0        POLYGON ((20.49832 44.76884, 20.49835 44.76890...
# 1        POLYGON ((20.50605 44.76544, 20.50611 44.76550...
# 2        POLYGON ((20.50625 44.76536, 20.50634 44.76546...
# 3        POLYGON ((20.50635 44.76534, 20.50647 44.76547...
# 4        POLYGON ((20.50653 44.76531, 20.50660 44.76538...
# ...                                                    ...
# 1383932  POLYGON ((19.83878 43.85270, 19.83887 43.85276...
# 1383933  POLYGON ((19.83920 43.85243, 19.83925 43.85254...
# 1383934  POLYGON ((19.83917 43.85263, 19.83921 43.85268...
# 1383935  POLYGON ((19.84373 43.86708, 19.84383 43.86709...
# 1383936  POLYGON ((19.82726 43.85579, 19.82728 43.85588...
#
# [1383937 rows x 6 columns]

# %%
poly['type'].unique()
# Out:
# array([None, 'house', 'civic', 'office', 'apartments', 'school',
#        'parking', 'train_station', 'hotel', 'kindergarten', 'retail',
#        'transportation', 'military', 'hospital', 'roof', 'church',
#        'university', 'commercial', 'stadium', 'public', 'cathedral',
#        'industrial', 'residential', 'synagogue', 'warehouse',
#        'construction', 'government', 'roundhouse', 'chapel', 'gatehouse',
#        'wall', 'gazebo', 'toilets', 'undefined', 'service', 'dormitory',
#        'hangar', 'garages', 'detached', 'shed', 'farm_auxiliary',
#        'sports_centre', 'college', 'barn', 'mosque', 'supermarket',
#        'guardhouse', 'garage', 'terrace', 'dormitory;apartments', 'no',
#        'abandoned', 'greenhouse', 'manor', 'houseboat', 'farm',
#        'manufacture', 'fire_station', 'bank', 'dorm', 'monastery', 'hut',
#        'ruins', 'ship', 'grandstand', 'tower', 'water_tower', 'collapsed',
#        'yes;public', 'kiosk', 'religious', 'restaurant', 'windmill',
#        'sports_hall', 'cabin', 'silos', 'semidetached_house', 'stable',
#        'police', 'commercial;house', 'transformer_tower', 'bungalow',
#        'castle', 'clinic', 'courthouse', 'planinarski_dom_na_t', 'bunker',
#        'library', 'car_shop', 'car_repair', 'yes;church', 'house;yes',
#        'silo', 'container', 'tumulus', 'cowshed', 'transformer',
#        'engine_shed', 'pavilion', 'stilt_house', 'support', 'cafe',
#        'store', 'post_office', 'shool', 'semi', 'storage_tank', 'carport',
#        'static_caravan', 'sty', 'boathouse', 'apartments;yes',
#        'industrial;yes', 'log', 'brewery', 'tent', 'riding_hall',
#        'bridge', 'flor', 'houses', 'doctor', 'gasometer', 'kucica', 'tes',
#        'factory', 'Punđelov potok', 'substation', 'bus_station',
#        'roof;yes', 'guest_house', 'dog_house', 'bakehouse', 'outbuilding',
#        'hostel', 'ruin', 'barge', 'gymnasium'], dtype=object)
